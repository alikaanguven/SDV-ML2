# %%
import awkward as ak
import matplotlib.pyplot as plt

# %%
df = ak.from_parquet("/scratch-cbe/users/alikaan.gueven/ML_KAAN/run2/stop_M600_585_ct20_2018/vtx_PART-353best_val_epoch.parquet")

# %%
df_concat = []
for filename in df.fields:
    df_concat.append(df[filename])

# %%
arr_concat = ak.concatenate(df_concat)

# %%
plt.hist(arr_concat, bins=1000)
plt.show()

# %%
import numpy as np
plt.hist(arr_concat, bins=np.linspace(0.999600, 0.999780, 200))
plt.show()
