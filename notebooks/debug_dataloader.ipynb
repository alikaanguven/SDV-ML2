# %%
import random
import copy

import numpy as np
import awkward as ak
import uproot
import torch

from numba import njit
# from concurrent.futures import ThreadPoolExecutor


def superbatch_iterator(files, keys, superbatch_size=1024*100):
    """
    Reduces the overhead caused by reading data in small batches.
    Now the batch size and data load size are independent.
    WARNING: data load size should be a multiple of batch size.

    Parameters
    ----------
    files: file paths as in uproot.iterator
    keys: TBranch names in list
    superbatch_size: batch_size * multiplet 
    """
    arrays = []
    num_entries = 0
    iterator = uproot.iterate(files, keys, step_size=superbatch_size, library="ak", 
                             #  decompression_executor=ThreadPoolExecutor(max_workers=2) # -- parallel xz/zstd)
                              ) 

    for it in iterator:
        it_length = it.type.length

        if num_entries + it_length < superbatch_size:
            # Batch is missing some entries, get more entries
            arrays.append(it)
            num_entries += it_length
        else:
            # If batch is ready or more than ready, handle it
            remaining = superbatch_size - num_entries

            if remaining > 0:
                arrays.append(it[:remaining])
                yield ak.concatenate(arrays)  # next iteration starts directly after this line.
                arrays = [it[remaining:]]
                num_entries = it_length - remaining
            else:
                yield ak.concatenate(arrays)  # next iteration starts directly after this line.
                arrays = []
                num_entries = 0
                # arrays = [it]
                # num_entries = it_length

    if arrays:
        yield ak.concatenate(arrays)



class ModifiedUprootIterator(torch.utils.data.IterableDataset):
    def __init__(self, files, branches, shuffle=False, nWorkers=1, step_size=100):
        """
        Parameters
        ----------
        files : dict
                keys: "sig", "bkg"
                values: ['path_to_file:Events', ...]
        branches : dict
                dict of branches in TTree.
                keys should be ev, sv, tk.
                values should be of type list.
        nWorkers : int
                Files will be divided among the workers.
                Therefore, nWorkers determines number of divisions.
                nWorkers=0 will be treated as nWorkers=1.
        step_size : int
                number of Events to be read from the files at each iteration.
        """
        
        print('Initialize iterable dataset')
        self.files = files
        self.branches = branches

        self.branchList = [b for key, value in branches.items() if value is not None for b in value]
        
        self.step_size = step_size
        self.nWorkers = max(nWorkers, 1)
        self.shuffle = shuffle
        print('nWorkers: ', self.nWorkers)
        
        if self.shuffle:
            random.shuffle(self.files['sig'])
            if self.files['bkg']:
                random.shuffle(self.files['bkg'])

        if self.files['bkg']:
            self.workerBkgList = self._distribute_files(self.files['bkg'])
        else:
            self.workerBkgList = None
        self.workerSigList = self._copy_files(self.files['sig'], shuffle=self.shuffle)

        self.SigIteratorList = None
        self.BkgIteratorList = None
        self._refresh_iterators()
        
        self.x = None
        self.xSig = None
        self.xBkg = None

    
    def _distribute_files(self, files):
        return [[files[i] for i in range(len(files)) if i % self.nWorkers == worker_id] for worker_id in range(self.nWorkers)]

    def _copy_files(self, files, shuffle=True):
        workerList = []
        for worker_info_id in range(self.nWorkers):
            files_copy = copy.copy(files)
            if shuffle: random.shuffle(files_copy)
            workerList.append(files_copy)
        return workerList
        
    def _refresh_iterators(self, shuffle=False):
        self.workerSigList = self._copy_files(self.files['sig'], shuffle=shuffle)
        self.SigIteratorList = [superbatch_iterator(workerFiles, self.branchList, superbatch_size=self.step_size) for workerFiles in self.workerSigList]
        if self.workerBkgList:
            self.BkgIteratorList = [superbatch_iterator(workerFiles, self.branchList, superbatch_size=self.step_size) for workerFiles in self.workerBkgList]
        else:
            self.BkgIteratorList = None

    def __iter__(self):
        print('__iter__ is called.')
        if self.step_size <200: 
            self.step_size += 25
            print('step_size is increased to ', self.step_size)
        self._refresh_iterators(shuffle=self.shuffle)
        return self

    def update_step_size(self, new_step_size):
        self.step_size = new_step_size

    
    def __next__(self):
        worker_info = torch.utils.data.get_worker_info()
        worker_id = worker_info.id if worker_info else 0

        if self.BkgIteratorList:
            self.xBkg = next(self.BkgIteratorList[worker_id])
            try:
                self.xSig = next(self.SigIteratorList[worker_id])
            except StopIteration:
                print(f'Worker {worker_id}s SigIteratorList is exhausted. Loading again.')
                self.SigIteratorList[worker_id] = superbatch_iterator(self.workerSigList[worker_id], self.branchList, superbatch_size=self.step_size)
                self.xSig = next(self.SigIteratorList[worker_id])
            self.x = ak.concatenate([self.xBkg, self.xSig])
        else:
            self.xSig = next(self.SigIteratorList[worker_id])
            self.x = self.xSig

        if self.shuffle:
            self.x = self._shuffle_akArr(self.x)
        self._add_four_vector_branches()
        
        return self._prepare_output()


    def _shuffle_akArr(self, x):
        """ Shuffle awkward array. """
        idx = np.arange(len(x))
        np.random.shuffle(idx)
        return x[idx]

    
    def _add_four_vector_branches(self):
        if all(x in self.branchList for x in ['SDVTrack_pt', 'SDVTrack_eta', 'SDVTrack_phi']) and \
           any(x not in self.branchList for x in ['SDVTrack_E', 'SDVTrack_px', 'SDVTrack_py', 'SDVTrack_pz']):
            
            self.branches['tk'].extend(['SDVTrack_E', 'SDVTrack_px', 'SDVTrack_py', 'SDVTrack_pz'])
            E, px, py, pz = ptetaphim_to_epxpypz(self.x['SDVTrack_pt'], self.x['SDVTrack_eta'], self.x['SDVTrack_phi'])
            self.x['SDVTrack_E'] = E
            self.x['SDVTrack_px'] = px
            self.x['SDVTrack_py'] = py
            self.x['SDVTrack_pz'] = pz


    def _prepare_output(self):
        return pad_and_fill(self.x, self.branches, svDim=12, tkDim=10, fillValue=0.)


def ptetaphim_to_epxpypz(pt, eta, phi, m=0.13957):
    px = pt * np.cos(phi)
    py = pt * np.sin(phi)
    pz = pt * np.sinh(eta)
    E = np.sqrt(px*px + py*py + pz*pz + m*m)
    return (E, px, py, pz)


def pad_and_fill(X, branchDict, svDim=12, tkDim=10, fillValue=-9e10):
    def process_field(field, broadcast_to=None):
        ak_arr = X[field]
        if broadcast_to == 'sv':
            # Broadcast to any sv branch shape
            ak_arr, _ = ak.broadcast_arrays(ak_arr, X[branchDict['sv'][0]])
        else:
            pass
        flat = ak.flatten(ak_arr, axis=1)
        X_np = flat.to_numpy()
        return torch.tensor(X_np)

    X_dict = {}
    # print('X.fields: ', X.fields)
    for field in X.fields:
        if branchDict['ev'] and field in branchDict['ev']:
            if field.startswith('n'):
                X[field] = ak.values_astype(X[field], np.int32)
            elif field.startswith('Jet'):
                X[field] = X[field][:, 0]
            
            X_dict[field] = process_field(field, broadcast_to='sv')
        
        elif branchDict['sv'] and field in branchDict['sv']:
            X_dict[field] = process_field(field)
        
        elif branchDict['label'] and field in branchDict['label']:
            X_dict[field] = process_field(field)

        elif branchDict['tk'] and field in branchDict['tk']:
            trIdx = X.SDVIdxLUT_TrackIdx
            svIdx = X.SDVIdxLUT_SecVtxIdx
            n_sv =  X.nSDVSecVtx
            
            builder = ak.ArrayBuilder()
            deepTable(X[field], trIdx, svIdx, n_sv, builder)
            deepX = builder.snapshot()
            # print(deepX.type)
            # print('deepX: ', deepX)

            field_fillValue = {
                'SDVTrack_E': 1e3,
                'SDVTrack_pz': 0
            }.get(field, fillValue)         # Returns 'fillValue' if the 'field' does not exist.

            almost_flat = ak.flatten(deepX, axis=1)
            # print('almost_flat: ', almost_flat)
            padded = ak.pad_none(almost_flat, target=tkDim, clip=True, axis=1)
            filled = ak.fill_none(padded, field_fillValue, axis=1)

            X_np = filled.to_numpy()
            X_dict[field] = torch.tensor(X_np)

    return X_dict


@njit
def deepTable(tkBranch, trIdx, svIdx, n_sv, builder):
    """
    Takes the track level branch and converts its shape
    from: (nEvent * var * float32) to (nEvent * var * var * float32)
    representing the association of each tk with sv.

    svIdx: [[0, 0, 1, 1,  2, 2,  3,  3, ...], ...]
    trIdx: [[1, 3, 3, 28, 7, 8, 10, 11, ...], ...]
    n_sv:  [4, 0, 6, 1, 1, 7, ...]
    """
    # at event level depth already
    # every element added are at event level depth
    for ev in range(len(n_sv)):                   # 
        builder.begin_list()                      # adding sv level depth
        for sv in range(n_sv[ev]):                # for each vtx ... 
            builder.begin_list()
            for i2, col in enumerate(svIdx[ev]):  # getting an svIdx from the svIdxs for that event
                if col == sv:                     # if the same svIdx 
                    builder.append(tkBranch[ev][trIdx[ev][i2]])
            builder.end_list()
        builder.end_list()

# @njit
# def deepTable(tkBranch, trIdx, svIdx, n_sv, builder):
#     """
#     Highly optimized version assuming svIdx is sorted per event.
#     Avoids intermediate lists for maximum performance and minimum memory overhead.
#     """
#     for ev in range(len(n_sv)):
#         builder.begin_list()  # Event-level list
#         
#         num_sv_in_event = n_sv[ev]
#         if num_sv_in_event == 0:
#             builder.end_list()
#             continue
# 
#         association_idx = 0
#         event_svIdx = svIdx[ev]
#         num_associations = len(event_svIdx)
# 
#         # For each expected SV, collect its tracks
#         for sv_target in range(num_sv_in_event):
#             builder.begin_list()  # SV-level list
#             
#             # Scan forward through the associations for the current sv_target
#             while association_idx < num_associations and event_svIdx[association_idx] == sv_target:
#                 track_idx = trIdx[ev][association_idx]
#                 builder.append(tkBranch[ev][track_idx])
#                 association_idx += 1 # Move to the next association
#             
#             builder.end_list()
#         builder.end_list()

# %%
import datetime
import warnings
import random
import glob
import gc

import math
import numpy as np
import awkward as ak
import uproot
from sklearn.metrics import confusion_matrix
from numba import jit, njit

import torch
import torch.nn as nn

# import ParT
# from vtxLevelDataset2 import ModifiedUprootIterator

import matplotlib.pyplot as plt


warnings.filterwarnings("ignore", category=UserWarning)


print('CPU count: ', torch.multiprocessing.cpu_count())
# torch.set_num_threads(18)
# torch.set_num_threads(torch.multiprocessing.cpu_count())

def significance(s,b,b_err):
    """
    Median discovery significance
    Definition at slide 33:
    https://www.pp.rhul.ac.uk/~cowan/stat/cowan_munich16.pdf
    
    """
    return np.sqrt(2*((s+b)*np.log(((s+b)*(b+b_err*b_err))/(b*b+(s+b)*b_err*b_err+1e-20)) - 
                    (b*b/(b_err*b_err + 1e-20))*np.log(1+(b_err*b_err*s)/(b*(b+b_err*b_err)+1e-20))))




MLDATADIR = '/scratch-cbe/users/alikaan.gueven/ML_KAAN/MC2018/all/'
tmpSigList = glob.glob(f'{MLDATADIR}/stop*/**/*.root', recursive=True)
tmpSigList = [sig + ':Events' for sig in tmpSigList]
maxTrain = round(len(tmpSigList)*0.70)
maxVal   = round(len(tmpSigList)*1)

trainSigList = tmpSigList[:maxTrain]
valSigList   = tmpSigList[maxTrain:maxVal]

# trainBkgList = glob.glob(f'{MLDATADIR}/training_set/bkg_mix*.root')
# valBkgList = glob.glob(f'{MLDATADIR}/val_set/bkg_mix*.root')

# trainBkgList = glob.glob('/scratch-cbe/users/alikaan.gueven/ML_KAAN/train/training_set/bkg_mix*.root')
# valBkgList = glob.glob('/scratch-cbe/users/alikaan.gueven/ML_KAAN/train/val_set/bkg_mix*.root')


# trainBkgList = [elm + ':Events' for elm in trainBkgList]
# valBkgList = [elm + ':Events' for elm in valBkgList]


# trainDict = {
#     'sig': trainSigList,
#     'bkg': trainBkgList
# }
# 
# valDict = {
#     'sig': valSigList,
#     'bkg': valBkgList
# }

trainDict = {
    'sig': trainSigList,
    'bkg': None
}

valDict = {
    'sig': valSigList,
    'bkg': None
}



branchDict = {}
branchDict['ev'] = ['MET_phi',
                    'nSDVSecVtx', 
                    'Jet_phi', 'Jet_pt', 'Jet_eta'
                    ]

branchDict['sv'] = ['SDVSecVtx_pt', 
                    'SDVSecVtx_pAngle', 
                    'SDVSecVtx_charge', 
                    'SDVSecVtx_ndof', 
                    'SDVSecVtx_chi2', 
                    'SDVSecVtx_tracksSize', 
                    'SDVSecVtx_sum_tkW', 
                    'SDVSecVtx_LxySig', 
                    'SDVSecVtx_L_phi', 
                    'SDVSecVtx_L_eta', 
                    'SDVIdxLUT_SecVtxIdx', 
                    'SDVIdxLUT_TrackIdx']

branchDict['tk'] = ['SDVTrack_pt', 'SDVTrack_ptError', 
                    'SDVTrack_eta', 'SDVTrack_etaError',
                    'SDVTrack_dxy', 'SDVTrack_dxyError', 
                    'SDVTrack_dz', 'SDVTrack_dzError',
                    'SDVTrack_normalizedChi2', 'SDVTrack_eta', 'SDVTrack_phi']
branchDict['label'] = ['SDVSecVtx_matchedLLPnDau_bydau']


shuffle = True
nWorkers = 2
step_size = 150

# trainDataset = ModifiedUprootIterator(trainDict, branchDict, shuffle=shuffle, nWorkers=min(nWorkers, len(trainBkgList)), step_size=step_size)
# trainLoader = torch.utils.data.DataLoader(trainDataset, num_workers=max(min(nWorkers, len(trainBkgList)),1), prefetch_factor=1, persistent_workers= True)
# 
# 
# valDataset = ModifiedUprootIterator(valDict, branchDict, shuffle=shuffle, nWorkers=min(nWorkers, len(valBkgList)), step_size=step_size*5)
# valLoader = torch.utils.data.DataLoader(valDataset, num_workers=max(min(nWorkers, len(valBkgList)),1), prefetch_factor=1, persistent_workers= True)
# Out:
# CPU count:  76

# %%
trainDataset = ModifiedUprootIterator(trainDict, branchDict, shuffle=shuffle, nWorkers=1, step_size=step_size)
trainLoader = torch.utils.data.DataLoader(trainDataset, num_workers=1, prefetch_factor=1, persistent_workers= True)
# Out:
# Initialize iterable dataset
# nWorkers:  1

# %%
# %%timeit
# tensor_dict = trainDataset.__next__()

# %%
tensor_dict = trainDataset.__next__()

# %%
# %prun -s cumulative [trainDataset.__next__() for _ in range(50)]
# Out:
#          28617731 function calls (28219062 primitive calls) in 29.540 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   29.549   29.549 {built-in method builtins.exec}
#         1    0.005    0.005   29.549   29.549 <string>:1(<module>)
#         1    0.000    0.000   29.544   29.544 <string>:1(<listcomp>)
#        50    0.005    0.000   29.544    0.591 1058244011.py:147(__next__)
# 22050/14300    0.018    0.000   25.526    0.002 {built-in method builtins.next}
#        50    0.007    0.000   20.257    0.405 1058244011.py:13(superbatch_iterator)
#        54    0.003    0.000   18.936    0.351 TBranch.py:49(iterate)
# 182329/561    2.033    0.000   17.004    0.030 model.py:754(read)
#         8    0.000    0.000   16.329    2.041 _util.py:954(regularize_object_path)
#         8    0.000    0.000   16.290    2.036 reading.py:2072(__getitem__)
#         8    0.000    0.000   16.290    2.036 reading.py:2459(get)
#   27960/8    0.135    0.000   16.222    2.028 model.py:1288(read)
#         8    0.001    0.000   16.143    2.018 TTree.py:687(read_members)
#  27968/16    0.232    0.000   16.135    1.008 TObjArray.py:30(read_members)
# 55912/27960    0.387    0.000   16.086    0.001 deserialization.py:187(read_object_any)
#     13976    0.426    0.000   14.512    0.001 TBranch.py:436(read_members)
#        50    0.001    0.000    7.222    0.144 1058244011.py:190(_prepare_output)
#        50    0.068    0.001    7.220    0.144 1058244011.py:202(pad_and_fill)
# 12262/8012    0.135    0.000    7.092    0.001 _dispatch.py:35(dispatch)
#    702357    1.306    0.000    3.775    0.000 chunk.py:421(get)
#    167784    1.087    0.000    3.274    0.000 deserialization.py:103(numbytes_version)
#      8328    0.039    0.000    3.153    0.000 TLeaf.py:94(read_members)
#    125848    0.200    0.000    3.036    0.000 model.py:874(read_numbytes_version)
#     40974    0.029    0.000    2.846    0.000 content.py:511(__getitem__)
#    323331    0.373    0.000    2.845    0.000 cursor.py:175(fields)
# 41024/40974    0.144    0.000    2.817    0.000 content.py:514(_getitem)
#        62    0.015    0.000    2.597    0.042 TBranch.py:881(iterate)
#      1300    0.013    0.000    2.521    0.002 _broadcasting.py:951(broadcast_and_apply)
#    702389    2.090    0.000    2.310    0.000 chunk.py:368(__contains__)
# 3246561/3246525    0.751    0.000    2.241    0.000 {built-in method builtins.isinstance}
#       400    0.005    0.000    2.207    0.006 highlevel.py:1079(__setitem__)
#    182329    0.391    0.000    2.204    0.000 model.py:915(check_numbytes)
#     27960    0.130    0.000    2.155    0.000 TNamed.py:18(read_members)
#       800    0.001    0.000    2.146    0.003 ak_with_field.py:18(with_field)
#       400    0.011    0.000    2.145    0.005 ak_with_field.py:51(_impl)
#        54    0.023    0.000    2.102    0.039 TBranch.py:2956(_ranges_or_baskets_to_arrays)
#     13976    0.099    0.000    2.084    0.000 TLeaf.py:27(read_members)
#        50    0.001    0.000    2.028    0.041 1058244011.py:178(_add_four_vector_branches)
#     82116    0.551    0.000    1.835    0.000 index.py:46(__init__)
# 4100/1300    0.048    0.000    1.800    0.001 _broadcasting.py:402(apply_step)
#     72362    0.312    0.000    1.794    0.000 index.py:225(__getitem__)
# 2800/1300    0.016    0.000    1.735    0.001 _broadcasting.py:892(continuation)
# 2200/1300    0.058    0.000    1.711    0.001 _broadcasting.py:535(broadcast_any_list)
#    184649    0.201    0.000    1.551    0.000 model.py:405(classname)
#       900    0.008    0.000    1.533    0.002 1058244011.py:203(process_field)
#      2394    0.006    0.000    1.499    0.001 futures.py:100(submit)
#     97944    0.271    0.000    1.468    0.000 reading.py:1083(class_named)
#      1100    0.009    0.000    1.441    0.001 _do.py:21(recursively_apply)
#      1400    0.003    0.000    1.411    0.001 ak_fill_none.py:17(fill_none)
#       700    0.013    0.000    1.408    0.002 ak_fill_none.py:71(_impl)
#    382236    0.603    0.000    1.352    0.000 typing.py:2009(__instancecheck__)
#    184649    0.639    0.000    1.281    0.000 model.py:173(classname_decode)
#     55928    0.376    0.000    1.277    0.000 TObject.py:26(read_members)
#      3500    0.011    0.000    1.265    0.000 dispatcher.py:679(typeof_pyval)
# 6300/3500    0.013    0.000    1.253    0.000 typeof.py:27(typeof)
# 6300/3500    0.012    0.000    1.243    0.000 functools.py:904(wrapper)
#     84056    0.097    0.000    1.226    0.000 cursor.py:394(string)
#      2800    0.003    0.000    1.215    0.000 __init__.py:203(typeof_Array)
#      2800    0.017    0.000    1.211    0.000 highlevel.py:53(wrapper)
#      2800    0.019    0.000    1.188    0.000 highlevel.py:1536(numba_type)
#     31000    0.064    0.000    1.182    0.000 indexedarray.py:299(_getitem_range)
#       900    0.006    0.000    1.176    0.001 recordarray.py:429(_getitem_range)
#       100    0.000    0.000    1.132    0.011 ak_concatenate.py:26(concatenate)
#        50    0.002    0.000    1.130    0.023 ak_concatenate.py:94(_impl)
#     84056    0.489    0.000    1.094    0.000 cursor.py:361(bytestring)
#        50    0.000    0.000    1.094    0.022 ak_concatenate.py:160(<listcomp>)
#        50    0.001    0.000    1.094    0.022 _do.py:253(mergemany)
#        50    0.014    0.000    1.093    0.022 recordarray.py:666(_mergemany)
#      2800    0.031    0.000    1.083    0.000 arrayview.py:204(fromarray)
#     97944    0.137    0.000    1.046    0.000 model.py:149(classname_regularize)
#       900    0.015    0.000    1.046    0.001 recordarray.py:447(<listcomp>)
#    153784    0.192    0.000    1.037    0.000 cursor.py:203(field)
#        50    0.003    0.000    0.922    0.018 1058244011.py:194(ptetaphim_to_epxpypz)
#       650    0.007    0.000    0.917    0.001 highlevel.py:1449(__array_ufunc__)
#      3776    0.020    0.000    0.902    0.000 TLeaf.py:436(read_members)
#      1300    0.010    0.000    0.892    0.001 listoffsetarray.py:802(_mergemany)
#       650    0.008    0.000    0.885    0.001 numpy.py:358(array_ufunc)
#     97944    0.096    0.000    0.875    0.000 __init__.py:178(sub)
#      4600    0.034    0.000    0.834    0.000 highlevel.py:634(__getitem__)
#       553    0.004    0.000    0.794    0.001 TBranch.py:3023(chunk_to_basket)
#       561    0.008    0.000    0.777    0.001 compression.py:365(decompress)
#      3200    0.003    0.000    0.770    0.000 ak_flatten.py:16(flatten)
#      1600    0.017    0.000    0.767    0.000 ak_flatten.py:175(_impl)
#       553    0.019    0.000    0.762    0.001 TBasket.py:214(read_members)
#       561    0.002    0.000    0.756    0.001 compression.py:191(decompress)
#       561    0.753    0.001    0.753    0.001 {built-in method xz.decompress}
#     10204    0.141    0.000    0.744    0.000 _kernels.py:88(__call__)
#    282593    0.442    0.000    0.733    0.000 {method 'sub' of 're.Pattern' objects}
#       400    0.001    0.000    0.732    0.002 ak_with_field.py:96(purelist_is_record)
#       700    0.005    0.000    0.705    0.001 regulararray.py:1384(_recursively_apply)
#      1841    0.028    0.000    0.698    0.000 TBranch.py:3044(basket_to_array)
#   1059643    0.369    0.000    0.658    0.000 {built-in method builtins.issubclass}
#       400    0.003    0.000    0.656    0.002 recordarray.py:1157(_recursively_apply)
#     11404    0.041    0.000    0.656    0.000 ak_to_layout.py:147(_impl)
#       400    0.009    0.000    0.652    0.002 recordarray.py:1166(<listcomp>)
#      1600    0.003    0.000    0.649    0.000 _do.py:232(flatten)
#    103736    0.107    0.000    0.647    0.000 array_module.py:50(asarray)
#       700    0.005    0.000    0.645    0.001 regulararray.py:1405(continuation)
#       450    0.002    0.000    0.642    0.001 _operators.py:50(func)
#       700    0.047    0.000    0.626    0.001 indexedoptionarray.py:1632(_recursively_apply)
#      2850    0.002    0.000    0.625    0.000 _broadcasting.py:986(<genexpr>)
#      1550    0.004    0.000    0.623    0.000 _broadcasting.py:110(broadcast_unpack)
#       600    0.003    0.000    0.612    0.001 _broadcasting.py:845(broadcast_any_indexed)
#      1750    0.007    0.000    0.608    0.000 regulararray.py:287(_getitem_at)
#     69586    0.055    0.000    0.599    0.000 _kernels.py:92(<genexpr>)
#      1300    0.065    0.000    0.596    0.000 listarray.py:1088(_mergemany)
#     14204    0.047    0.000    0.590    0.000 listoffsetarray.py:321(_getitem_range)
#      1450    0.008    0.000    0.544    0.000 ak_from_iter.py:18(from_iter)
#     59382    0.191    0.000    0.544    0.000 _kernels.py:68(_cast)
#      3066    0.010    0.000    0.543    0.000 queue.py:154(get)
#      1450    0.028    0.000    0.536    0.000 ak_from_iter.py:73(_impl)
#      1404    0.093    0.000    0.526    0.000 jagged.py:222(final_array)
#      6876    0.522    0.000    0.522    0.000 {method 'acquire' of '_thread.lock' objects}
#        32    0.000    0.000    0.520    0.016 threading.py:295(wait)
#       650    0.003    0.000    0.510    0.001 indexedarray.py:490(_offsets_and_flattened)
#      2150    0.016    0.000    0.506    0.000 ak_from_buffers.py:117(_impl)
#      1400    0.003    0.000    0.489    0.000 ak_fill_none.py:112(action)
#       700    0.001    0.000    0.480    0.001 _do.py:241(fill_none)
#       700    0.016    0.000    0.478    0.001 indexedoptionarray.py:837(_fill_none)
#       500    0.001    0.000    0.468    0.001 ak_broadcast_arrays.py:21(broadcast_arrays)
#       250    0.003    0.000    0.467    0.002 ak_broadcast_arrays.py:205(_impl)
#     14012    0.101    0.000    0.466    0.000 _errors.py:228(__init__)
#      1512    0.023    0.000    0.458    0.000 library.py:509(finalize)
# 7500/2800    0.026    0.000    0.456    0.000 arrayview.py:112(to_numbatype)
#      2800    0.006    0.000    0.430    0.000 arrayview.py:157(__init__)
#      1950    0.023    0.000    0.427    0.000 listarray.py:271(to_ListOffsetArray64)
#      2800    0.015    0.000    0.424    0.000 _lookup.py:12(__init__)
#     82116    0.071    0.000    0.424    0.000 array_module.py:72(ascontiguousarray)
#     12962    0.113    0.000    0.424    0.000 _layout.py:194(wrap_layout)
#      2600    0.012    0.000    0.413    0.000 layout.py:633(from_form)
# 5000/2150    0.065    0.000    0.407    0.000 ak_from_buffers.py:187(_reconstitute)
#     18500    0.044    0.000    0.398    0.000 abstract.py:61(__call__)
#      7454    0.031    0.000    0.392    0.000 _layout.py:127(unwrap)
#     31290    0.119    0.000    0.382    0.000 dispatch.py:72(backend_of_obj)
# 12628/11116    0.074    0.000    0.375    0.000 highlevel.py:271(__init__)
#    392618    0.268    0.000    0.371    0.000 _awkwardforth.py:130(get_forth_obj)
#     15170    0.083    0.000    0.369    0.000 numpyarray.py:115(__init__)
#      1300    0.022    0.000    0.354    0.000 indexedarray.py:431(project)
#       700    0.029    0.000    0.350    0.001 unionarray.py:223(simplified)
#     87132    0.070    0.000    0.349    0.000 content.py:123(_init)
#      1448    0.008    0.000    0.344    0.000 TLeaf.py:271(read_members)
#       700    0.010    0.000    0.332    0.000 highlevel.py:2741(snapshot)
#     32800    0.159    0.000    0.329    0.000 indexedarray.py:106(__init__)
#      7800    0.006    0.000    0.326    0.000 ak_to_layout.py:30(to_layout)
#     13704    0.047    0.000    0.326    0.000 highlevel.py:1191(__getattr__)
#    196938    0.246    0.000    0.318    0.000 cursor.py:109(copy)
#       650    0.002    0.000    0.317    0.000 listarray.py:1061(_offsets_and_flattened)
#   1461897    0.241    0.000    0.316    0.000 {method 'get' of 'dict' objects}
#    428021    0.151    0.000    0.313    0.000 <frozen abc>:117(__instancecheck__)
#     82866    0.136    0.000    0.312    0.000 numerictypes.py:357(issubdtype)
# 16874/16424    0.063    0.000    0.309    0.000 _errors.py:204(any_backend_is_delayed)
#    440414    0.161    0.000    0.307    0.000 <frozen abc>:121(__subclasscheck__)
#    511858    0.305    0.000    0.305    0.000 {method 'match' of 're.Pattern' objects}
#      1600    0.004    0.000    0.303    0.000 highlevel.py:501(to_numpy)
#     10800    0.024    0.000    0.303    0.000 index.py:111(empty)
#    986662    0.246    0.000    0.291    0.000 {built-in method builtins.getattr}
#     25258    0.130    0.000    0.286    0.000 listoffsetarray.py:117(__init__)
#         8    0.024    0.003    0.270    0.034 TBranch.py:2571(_keys_deep)
#     98368    0.214    0.000    0.266    0.000 __init__.py:272(_compile)
#      1200    0.031    0.000    0.265    0.000 listarray.py:392(_broadcast_tooffsets64)
# 7500/2800    0.025    0.000    0.258    0.000 _lookup.py:32(tolookup)
#     13976    0.172    0.000    0.255    0.000 TBranch.py:2391(postprocess)
#      1400    0.002    0.000    0.254    0.000 ak_pad_none.py:16(pad_none)
#       700    0.005    0.000    0.252    0.000 ak_pad_none.py:115(_impl)
#      2100    0.011    0.000    0.240    0.000 layout.py:542(from_form)
#     41944    0.061    0.000    0.233    0.000 cursor.py:330(array)
# 286464/227618    0.177    0.000    0.233    0.000 model.py:531(member)
#       850    0.005    0.000    0.232    0.000 ak_with_field.py:117(action)
#     23512    0.030    0.000    0.228    0.000 {built-in method builtins.all}
#     55936    0.106    0.000    0.227    0.000 model.py:234(classname_version)
#      2600    0.011    0.000    0.223    0.000 _lookup.py:147(tolookup)
#      4600    0.052    0.000    0.222    0.000 _errors.py:312(__init__)
#      6154    0.007    0.000    0.221    0.000 listoffsetarray.py:184(starts)
#      1300    0.011    0.000    0.220    0.000 _broadcasting.py:356(broadcast_to_offsets_avoiding_carry)
#      1600    0.012    0.000    0.212    0.000 listoffsetarray.py:702(_offsets_and_flattened)
#      2100    0.014    0.000    0.211    0.000 _lookup.py:125(tolookup)
#     13984    0.006    0.000    0.204    0.000 TBranch.py:1318(itervalues)
#       700    0.002    0.000    0.203    0.000 _do.py:188(pad_none)
#       700    0.021    0.000    0.202    0.000 listoffsetarray.py:1774(_pad_none)
#      2900    0.013    0.000    0.201    0.000 listoffsetarray.py:253(to_ListOffsetArray64)
#     34866    0.039    0.000    0.200    0.000 numpy.py:50(is_c_contiguous)
# 27960/13984    0.058    0.000    0.198    0.000 TBranch.py:1355(iteritems)
#       600    0.001    0.000    0.192    0.000 _broadcasting.py:849(<listcomp>)
#    477115    0.191    0.000    0.191    0.000 {method 'unpack' of '_struct.Struct' objects}
#      1454    0.076    0.000    0.191    0.000 recordarray.py:149(__init__)
#       700    0.003    0.000    0.191    0.000 indexedarray.py:1154(_push_inside_record_or_project)
#      1350    0.010    0.000    0.188    0.000 listoffsetarray.py:352(_carry)
#     13976    0.020    0.000    0.178    0.000 cursor.py:152(skip_over)
#      6154    0.005    0.000    0.175    0.000 listoffsetarray.py:188(stops)
#       400    0.005    0.000    0.173    0.000 ak_with_field.py:150(<listcomp>)
#      2100    0.025    0.000    0.168    0.000 numpyarray.py:497(_mergemany)
#     17912    0.019    0.000    0.167    0.000 recordarray.py:454(_getitem_field)
#      3200    0.002    0.000    0.167    0.000 ak_to_numpy.py:12(to_numpy)
#      1600    0.017    0.000    0.165    0.000 ak_to_numpy.py:51(_impl)
#    165732    0.108    0.000    0.164    0.000 numerictypes.py:283(issubclass_)
#    428021    0.143    0.000    0.162    0.000 {built-in method _abc._abc_instancecheck}
#      2800    0.016    0.000    0.161    0.000 layout.py:410(from_form)
#    702405    0.149    0.000    0.159    0.000 chunk.py:376(wait)
#      4700    0.012    0.000    0.157    0.000 layout.py:157(from_form_index)
#       700    0.152    0.000    0.152    0.000 1058244011.py:258(deepTable)
#     12628    0.023    0.000    0.150    0.000 highlevel.py:354(_update_class)
#    440414    0.146    0.000    0.146    0.000 {built-in method _abc._abc_subclasscheck}
#     51248    0.044    0.000    0.145    0.000 dispatch.py:37(lookup_factory)
#     17912    0.034    0.000    0.145    0.000 recordarray.py:393(content)
#      3500    0.008    0.000    0.144    0.000 _layout.py:156(wrap)
#     41774    0.054    0.000    0.144    0.000 _regularize.py:34(is_integer_like)
#        50    0.002    0.000    0.143    0.003 indexedarray.py:1058(_recursively_apply)
#     13800    0.014    0.000    0.143    0.000 _errors.py:317(<genexpr>)
#    694252    0.141    0.000    0.142    0.000 {built-in method builtins.hasattr}
#     64116    0.051    0.000    0.139    0.000 array_module.py:694(is_own_array)
#      5458    0.015    0.000    0.137    0.000 numpyarray.py:322(_getitem_range)
#    182329    0.097    0.000    0.137    0.000 deserialization.py:149(numbytes_check)
#    460906    0.136    0.000    0.136    0.000 {method 'startswith' of 'str' objects}
#      2250    0.021    0.000    0.134    0.000 numpy.py:368(action)
#     79368    0.107    0.000    0.133    0.000 highlevel.py:1241(__setattr__)
#      7500    0.030    0.000    0.130    0.000 npytypes.py:444(__init__)
#     43718    0.017    0.000    0.127    0.000 TBranch.py:1855(name)
#     13984    0.037    0.000    0.125    0.000 TTree.py:894(read_members)
#      2150    0.008    0.000    0.122    0.000 form.py:201(from_json)
#     84104    0.062    0.000    0.122    0.000 _util.py:34(tobytes)
#     18500    0.022    0.000    0.121    0.000 abstract.py:49(_intern)
#      1562    0.007    0.000    0.120    0.000 ak_from_numpy.py:11(from_numpy)
#      5000    0.023    0.000    0.120    0.000 ak_from_buffers.py:154(_from_buffer)
#      2800    0.009    0.000    0.119    0.000 _lookup.py:28(<listcomp>)
#      2854    0.004    0.000    0.119    0.000 content.py:188(form)
#      2900    0.008    0.000    0.118    0.000 index.py:241(to64)
#    124280    0.075    0.000    0.116    0.000 <frozen _collections_abc>:989(__iter__)
#      2400    0.057    0.000    0.116    0.000 numpyarray.py:342(_carry)
#     13984    0.032    0.000    0.116    0.000 TAtt.py:244(read_members)
#      1050    0.012    0.000    0.116    0.000 listarray.py:366(_compact_offsets64)
#      2854    0.004    0.000    0.115    0.000 content.py:192(form_with_key)
#     97944    0.113    0.000    0.113    0.000 __init__.py:315(_subx)
#      1566    0.002    0.000    0.113    0.000 library.py:505(imported)
#      5900    0.031    0.000    0.111    0.000 regulararray.py:123(__init__)
#     14300    0.045    0.000    0.110    0.000 _lookup.py:16(arrayptr)
#      1566    0.007    0.000    0.110    0.000 extras.py:19(awkward)
#     13984    0.066    0.000    0.103    0.000 model.py:139(_classname_decode_convert)
#      3250    0.011    0.000    0.101    0.000 array_module.py:171(array_equal)
# 406346/403499    0.091    0.000    0.101    0.000 {built-in method builtins.len}
#      3132    0.004    0.000    0.101    0.000 _util.py:115(parse_version)
#       416    0.002    0.000    0.098    0.000 TLeaf.py:153(read_members)
#      3132    0.004    0.000    0.097    0.000 version.py:47(parse)
#      1562    0.019    0.000    0.097    0.000 _layout.py:253(from_arraylib)
#         8    0.001    0.000    0.097    0.012 TBranch.py:2814(_regularize_expressions)
#       232    0.001    0.000    0.096    0.000 TBranch.py:2726(_regularize_expression)
#     32458    0.031    0.000    0.096    0.000 {built-in method builtins.any}
#    288060    0.094    0.000    0.094    0.000 index.py:144(length)
#      3132    0.039    0.000    0.094    0.000 version.py:188(__init__)
#       150    0.003    0.000    0.093    0.001 regulararray.py:460(_getitem_next)
#      1600    0.093    0.000    0.093    0.000 {built-in method torch.tensor}
#    114750    0.055    0.000    0.091    0.000 indexedarray.py:250(length)
#       650    0.007    0.000    0.090    0.000 numpy.py:150(_array_ufunc_custom_cast)
#      1450    0.008    0.000    0.089    0.000 listoffsetarray.py:306(_getitem_at)
#     25562    0.032    0.000    0.086    0.000 jax.py:45(is_own_array_type)
#     31916    0.023    0.000    0.083    0.000 _regularize.py:26(is_integer)
#     12628    0.055    0.000    0.083    0.000 _behavior.py:35(get_array_class)
#     20912    0.057    0.000    0.083    0.000 array_module.py:329(derive_slice_for_length)
#    268753    0.082    0.000    0.082    0.000 {method 'decode' of 'bytes' objects}
#      2600    0.009    0.000    0.081    0.000 indexedarray.py:208(_form_with_key)
#      5150    0.040    0.000    0.080    0.000 listarray.py:124(__init__)
#         8    0.012    0.002    0.078    0.010 TTree.py:154(postprocess)
#     17912    0.026    0.000    0.077    0.000 recordmeta.py:132(content)
#      7500    0.045    0.000    0.077    0.000 common.py:49(__init__)
# 5000/2150    0.030    0.000    0.076    0.000 form.py:50(from_dict)
#      3504    0.010    0.000    0.074    0.000 listoffsetarray.py:192(_form_with_key)
#        50    0.000    0.000    0.074    0.001 indexedarray.py:1103(continuation)
#     13984    0.016    0.000    0.074    0.000 __init__.py:321(filter)
#    198092    0.072    0.000    0.072    0.000 cursor.py:48(__init__)
#    191761    0.070    0.000    0.070    0.000 {built-in method __new__ of type object at 0x55b4230f0000}
#    184649    0.069    0.000    0.069    0.000 model.py:416(encoded_classname)
#      6462    0.023    0.000    0.069    0.000 numpyform.py:49(__init__)
#      4312    0.017    0.000    0.069    0.000 numpyarray.py:190(_form_with_key)
#    210273    0.068    0.000    0.068    0.000 cursor.py:95(displacement)
#    168417    0.068    0.000    0.068    0.000 cursor.py:127(skip)
#         8    0.000    0.000    0.067    0.008 reading.py:2549(get_uncompressed_chunk_cursor)
#     25714    0.008    0.000    0.067    0.000 TBranch.py:1881(cache_key)
#      1300    0.010    0.000    0.065    0.000 _broadcasting.py:84(broadcast_pack)
#      1562    0.007    0.000    0.065    0.000 _layout.py:267(recurse)
#       150    0.003    0.000    0.064    0.000 indexedarray.py:375(_getitem_next)
#       232    0.001    0.000    0.062    0.000 TBranch.py:2663(_regularize_branchname)
#      2100    0.036    0.000    0.061    0.000 array_module.py:441(concat)
#     18612    0.034    0.000    0.061    0.000 _errors.py:70(__enter__)
#      3250    0.026    0.000    0.061    0.000 numeric.py:2378(array_equal)
#      7500    0.009    0.000    0.060    0.000 __init__.py:183(dumps)
#     27506    0.041    0.000    0.060    0.000 numpytype.py:45(dtype_to_primitive)
#     28224    0.048    0.000    0.059    0.000 _util.py:45(isint)
#     55836    0.046    0.000    0.059    0.000 _errors.py:63(primary)
#     13984    0.050    0.000    0.058    0.000 _parser.py:1099(expand_template)
#        54    0.000    0.000    0.058    0.001 library.py:613(group)
#    118486    0.058    0.000    0.058    0.000 {built-in method numpy.asarray}
#     43739    0.057    0.000    0.057    0.000 {built-in method numpy.frombuffer}
#      2150    0.057    0.000    0.057    0.000 {built-in method awkward_cpp.lib._ext.to_buffers}
#     32066    0.057    0.000    0.057    0.000 __init__.py:511(cast)
#    231736    0.056    0.000    0.056    0.000 {method 'group' of 're.Match' objects}
#      1727    0.012    0.000    0.056    0.000 jagged.py:139(basket_array)
# 117436/117212    0.055    0.000    0.055    0.000 model.py:518(has_member)
#     41666    0.055    0.000    0.055    0.000 _internal.py:250(__init__)
#     13984    0.029    0.000    0.055    0.000 cursor.py:134(skip_after)
#    240593    0.055    0.000    0.055    0.000 {method 'encode' of 'str' objects}
#     55936    0.040    0.000    0.054    0.000 model.py:1224(class_of_version)
#     18612    0.026    0.000    0.053    0.000 _errors.py:77(__exit__)
#     12628    0.014    0.000    0.052    0.000 content.py:911(purelist_parameter)
#    253668    0.052    0.000    0.052    0.000 content.py:184(backend)
#     14537    0.012    0.000    0.052    0.000 cursor.py:310(bytes)
#       224    0.016    0.000    0.051    0.000 TBranch.py:1892(index)
#      7500    0.019    0.000    0.051    0.000 encoder.py:183(encode)
#     55086    0.032    0.000    0.051    0.000 listoffsetarray.py:234(length)
#       650    0.002    0.000    0.050    0.000 array_module.py:197(apply_ufunc)
#    101076    0.049    0.000    0.049    0.000 {method 'search' of 're.Pattern' objects}
#     12812    0.015    0.000    0.048    0.000 highlevel.py:3132(find_highlevel_backend)
#      1600    0.002    0.000    0.048    0.000 content.py:1013(to_backend_array)
#       650    0.012    0.000    0.047    0.000 array_module.py:224(_apply_ufunc_nep_50)
#      7754    0.008    0.000    0.047    0.000 dispatch.py:125(regularize_backend)
#      5750    0.015    0.000    0.046    0.000 array_module.py:295(reshape)
#      3450    0.019    0.000    0.044    0.000 content.py:753(_merging_strategy)
#      2800    0.005    0.000    0.044    0.000 arrayview.py:242(typeof_ArrayView)
#    226006    0.043    0.000    0.043    0.000 numpy.py:28(index_nplike)
#    226835    0.043    0.000    0.043    0.000 {method 'append' of 'list' objects}
#      2800    0.010    0.000    0.042    0.000 layout.py:416(__init__)
#    167800    0.042    0.000    0.042    0.000 model.py:484(concrete)
#      5550    0.042    0.000    0.042    0.000 {method 'reduce' of 'numpy.ufunc' objects}
# 26000/18500    0.022    0.000    0.042    0.000 abstract.py:121(__hash__)
#    124504    0.041    0.000    0.041    0.000 TObjArray.py:91(__getitem__)
#       250    0.007    0.000    0.041    0.000 regulararray.py:399(_broadcast_tooffsets64)
#    182383    0.040    0.000    0.040    0.000 reading.py:209(file_path)
#       108    0.004    0.000    0.039    0.000 numerical.py:45(final_array)
#     51428    0.031    0.000    0.039    0.000 numpy.py:39(is_own_array_type)
#     12628    0.015    0.000    0.039    0.000 meta.py:54(purelist_parameter)
#      2350    0.011    0.000    0.039    0.000 dispatch.py:91(backend_of)
#      6300    0.006    0.000    0.038    0.000 _layout.py:72(__exit__)
#      2150    0.006    0.000    0.038    0.000 __init__.py:299(loads)
#        54    0.001    0.000    0.037    0.001 highlevel.py:560(type)
#     12974    0.021    0.000    0.037    0.000 numpytype.py:28(primitive_to_dtype)
#    181776    0.037    0.000    0.037    0.000 model.py:654(is_memberwise)
#      2800    0.006    0.000    0.035    0.000 _lookup.py:83(tolookup)
# 4220/4116    0.005    0.000    0.035    0.000 {built-in method builtins.max}
#       700    0.003    0.000    0.035    0.000 indexedoptionarray.py:323(_getitem_range)
#      2460    0.014    0.000    0.035    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#     84104    0.035    0.000    0.035    0.000 {method 'tobytes' of 'numpy.ndarray' objects}
#    155886    0.034    0.000    0.034    0.000 index.py:123(nplike)
#     78224    0.034    0.000    0.034    0.000 _slicing.py:25(normalize_slice)
#     14262    0.008    0.000    0.034    0.000 typetracer.py:1685(is_own_array_type)
#      2850    0.003    0.000    0.033    0.000 _broadcasting.py:634(<genexpr>)
#     14524    0.025    0.000    0.033    0.000 <frozen importlib._bootstrap>:1207(_handle_fromlist)
#     18500    0.022    0.000    0.033    0.000 abstract.py:124(__eq__)
#      3250    0.005    0.000    0.033    0.000 {method 'all' of 'numpy.ndarray' objects}
#      6300    0.021    0.000    0.032    0.000 _layout.py:93(finalize)
#     25562    0.026    0.000    0.032    0.000 cupy.py:156(is_own_array_type)
#     25562    0.026    0.000    0.032    0.000 jax.py:56(is_array_type)
#      3150    0.004    0.000    0.032    0.000 array_module.py:683(astype)
#      2350    0.006    0.000    0.032    0.000 __init__.py:17(to_nplike)
#     12100    0.009    0.000    0.032    0.000 array_module.py:106(empty)
#      7454    0.025    0.000    0.032    0.000 _layout.py:113(update)
#      5604    0.006    0.000    0.031    0.000 content.py:1195(to_backend)
#       232    0.000    0.000    0.031    0.000 TBranch.py:1907(interpretation)
#        50    0.001    0.000    0.031    0.001 1058244011.py:171(_shuffle_akArr)
#    182329    0.031    0.000    0.031    0.000 model.py:980(hook_before_read_members)
#       224    0.003    0.000    0.031    0.000 identify.py:298(interpretation_of)
#    182329    0.031    0.000    0.031    0.000 model.py:974(hook_before_read)
#      3682    0.012    0.000    0.030    0.000 queue.py:122(put)
#       700    0.007    0.000    0.030    0.000 regulararray.py:1225(_to_backend_array)
#      2150    0.009    0.000    0.030    0.000 decoder.py:332(decode)
#     97944    0.030    0.000    0.030    0.000 model.py:315(maybe_custom_classes)
#    182329    0.030    0.000    0.030    0.000 model.py:987(hook_after_read_members)
#    182329    0.030    0.000    0.030    0.000 model.py:994(hook_before_postprocess)
#     41952    0.029    0.000    0.029    0.000 model.py:141(<genexpr>)
#         8    0.001    0.000    0.029    0.004 reading.py:530(__init__)
#     15016    0.028    0.000    0.028    0.000 {built-in method numpy.empty}
#      3250    0.003    0.000    0.028    0.000 _methods.py:61(_all)
#    120944    0.028    0.000    0.028    0.000 cursor.py:85(refs)
#      1600    0.004    0.000    0.027    0.000 numpyarray.py:1218(_to_backend_array)
#     41774    0.019    0.000    0.027    0.000 _regularize.py:30(is_array_like)
#      2800    0.002    0.000    0.027    0.000 numpyarray.py:551(to_contiguous)
#       250    0.002    0.000    0.027    0.000 ak_broadcast_arrays.py:255(<listcomp>)
#      7500    0.027    0.000    0.027    0.000 encoder.py:205(iterencode)
#     32624    0.027    0.000    0.027    0.000 _errors.py:30(__init__)
#       150    0.006    0.000    0.027    0.000 listarray.py:701(_getitem_next)
#       800    0.003    0.000    0.026    0.000 array_module.py:274(broadcast_arrays)
#    168345    0.026    0.000    0.026    0.000 model.py:946(postprocess)
#      6400    0.004    0.000    0.026    0.000 dispatch.py:104(<genexpr>)
#      3200    0.012    0.000    0.026    0.000 _ufunc_config.py:33(seterr)
#    125130    0.025    0.000    0.025    0.000 numpy.py:24(nplike)
#     12854    0.016    0.000    0.025    0.000 highlevel.py:3136(finder)
#     10204    0.021    0.000    0.025    0.000 numpy.py:35(__getitem__)
#      2800    0.004    0.000    0.025    0.000 numpyarray.py:561(is_contiguous)
#     20890    0.016    0.000    0.025    0.000 _singleton.py:45(instance)
#       800    0.005    0.000    0.024    0.000 array_module.py:597(any)
#        24    0.000    0.000    0.024    0.001 fsspec.py:100(chunk)
#      1727    0.024    0.000    0.024    0.000 jagged.py:18(fast_divide)
#        54    0.008    0.000    0.024    0.000 python.py:392(compute_expressions)
#        54    0.000    0.000    0.024    0.000 recordarray.py:310(_form_with_key)
#      1150    0.004    0.000    0.023    0.000 _layout.py:170(ensure_same_backend)
# 18716/17316    0.019    0.000    0.023    0.000 listoffsetmeta.py:16(purelist_parameters)
#      3024    0.013    0.000    0.023    0.000 TBranch.py:1963(entry_offsets)
#        24    0.000    0.000    0.023    0.001 local.py:465(read)
#        24    0.023    0.001    0.023    0.001 {method 'read' of '_io.BufferedReader' objects}
#      2600    0.007    0.000    0.023    0.000 layout.py:641(__init__)
#      6412    0.003    0.000    0.022    0.000 array_module.py:447(<genexpr>)
#     25562    0.018    0.000    0.022    0.000 jax.py:68(is_tracer_type)
#      2100    0.007    0.000    0.022    0.000 layout.py:555(__init__)
#     19424    0.013    0.000    0.022    0.000 recordmeta.py:101(field_to_index)
#        54    0.001    0.000    0.022    0.000 recordarray.py:313(<listcomp>)
#     79374    0.022    0.000    0.022    0.000 index.py:127(dtype)
#      6800    0.004    0.000    0.022    0.000 dispatch.py:105(<genexpr>)
#      1550    0.006    0.000    0.021    0.000 fromnumeric.py:71(_wrapreduction)
#       250    0.002    0.000    0.020    0.000 ak_broadcast_arrays.py:221(<listcomp>)
#      1200    0.002    0.000    0.020    0.000 listarray.py:177(copy)
#     61062    0.020    0.000    0.020    0.000 index.py:131(metadata)
#      3132    0.015    0.000    0.019    0.000 version.py:504(_cmpkey)
#      1841    0.011    0.000    0.019    0.000 numerical.py:335(basket_array)
#      1600    0.004    0.000    0.019    0.000 _ufunc_config.py:430(__enter__)
#      1512    0.006    0.000    0.019    0.000 TBranch.py:2364(entries_to_ranges_or_baskets)
#       700    0.009    0.000    0.019    0.000 indexedoptionarray.py:295(mask_as_bool)
#      6104    0.017    0.000    0.019    0.000 _layout.py:365(maybe_posaxis)
#      4100    0.011    0.000    0.019    0.000 _broadcasting.py:130(ensure_common_length)
#      5350    0.004    0.000    0.019    0.000 _broadcasting.py:432(<genexpr>)
#     45866    0.015    0.000    0.019    0.000 recordarray.py:233(<genexpr>)
#      1400    0.010    0.000    0.019    0.000 indexedoptionarray.py:102(__init__)
# 26000/18500    0.010    0.000    0.018    0.000 {built-in method builtins.hash}
#     82116    0.018    0.000    0.018    0.000 {built-in method numpy.ascontiguousarray}
#       800    0.002    0.000    0.017    0.000 numpyarray.py:145(copy)
#        54    0.004    0.000    0.017    0.000 fsspec.py:121(chunks)
#      6300    0.009    0.000    0.017    0.000 functools.py:818(dispatch)
#      8100    0.009    0.000    0.017    0.000 indexedmeta.py:16(purelist_parameters)
#      5000    0.006    0.000    0.017    0.000 form.py:353(getkey)
#      1550    0.002    0.000    0.016    0.000 indexedarray.py:161(simplified)
#      2050    0.002    0.000    0.016    0.000 _broadcasting.py:698(<genexpr>)
#       750    0.002    0.000    0.016    0.000 array_module.py:608(min)
#     76686    0.016    0.000    0.016    0.000 {method 'partition' of 'str' objects}
#     37224    0.016    0.000    0.016    0.000 _errors.py:45(__init__)
#      2212    0.011    0.000    0.016    0.000 numpyarray.py:448(_mergeable_next)
#       800    0.003    0.000    0.015    0.000 stride_tricks.py:480(broadcast_arrays)
#        54    0.000    0.000    0.015    0.000 _do.py:249(mergeable)
#        50    0.001    0.000    0.015    0.000 indexedarray.py:1157(<listcomp>)
#      1450    0.015    0.000    0.015    0.000 {built-in method awkward_cpp.lib._ext.fromiter}
#        54    0.003    0.000    0.015    0.000 recordarray.py:630(_mergeable_next)
#       800    0.002    0.000    0.015    0.000 fromnumeric.py:2322(any)
#     12812    0.009    0.000    0.015    0.000 highlevel.py:3148(find_lowlevel_backend)
#      2900    0.001    0.000    0.014    0.000 typetracer.py:54(is_unknown_scalar)
#      6354    0.009    0.000    0.014    0.000 listoffsetform.py:30(__init__)
#     41666    0.014    0.000    0.014    0.000 _internal.py:304(data)
#      2800    0.009    0.000    0.014    0.000 arrayview.py:259(__init__)
#      9600    0.010    0.000    0.013    0.000 _broadcasting.py:304(is_string_like)
#      1600    0.003    0.000    0.013    0.000 _ufunc_config.py:435(__exit__)
#      1300    0.006    0.000    0.013    0.000 _broadcasting.py:327(broadcast_regular_dim_size)
#      7576    0.013    0.000    0.013    0.000 {method 'view' of 'numpy.ndarray' objects}
#      2250    0.010    0.000    0.013    0.000 numpy.py:210(_array_ufunc_signature)
#       700    0.001    0.000    0.013    0.000 __init__.py:211(typeof_ArrayBuilder)
#     12262    0.010    0.000    0.012    0.000 inspect.py:428(isgenerator)
#        54    0.000    0.000    0.012    0.000 recordform.py:104(type)
#      2150    0.012    0.000    0.012    0.000 decoder.py:343(raw_decode)
#       700    0.002    0.000    0.012    0.000 highlevel.py:2718(numba_type)
#     53982    0.012    0.000    0.012    0.000 meta.py:43(parameter)
#     14432    0.006    0.000    0.012    0.000 TBranch.py:561(branches)
#       700    0.002    0.000    0.012    0.000 indexedoptionarray.py:156(simplified)
#      3150    0.012    0.000    0.012    0.000 {method 'astype' of 'numpy.ndarray' objects}
#      1150    0.003    0.000    0.012    0.000 _layout.py:188(<listcomp>)
#       154    0.000    0.000    0.011    0.000 ak_concatenate.py:129(<genexpr>)
#     22500    0.011    0.000    0.011    0.000 npytypes.py:482(key)
#       104    0.003    0.000    0.011    0.000 recordmeta.py:42(minmax_depth)
#     52616    0.011    0.000    0.011    0.000 index.py:119(data)
#         8    0.000    0.000    0.011    0.001 fsspec.py:43(__init__)
#      6748    0.005    0.000    0.011    0.000 threading.py:366(notify)
#        54    0.001    0.000    0.011    0.000 recordform.py:107(<listcomp>)
#      1300    0.005    0.000    0.011    0.000 _broadcasting.py:60(length_of_broadcast)
#     27968    0.008    0.000    0.011    0.000 _util.py:175(regularize_filter)
#      5050    0.008    0.000    0.011    0.000 copy.py:66(copy)
#       224    0.001    0.000    0.011    0.000 identify.py:64(_leaf_to_dtype)
#      1404    0.004    0.000    0.010    0.000 listoffsetarray.py:778(_mergeable_next)
#      1230    0.006    0.000    0.010    0.000 ipkernel.py:790(<setcomp>)
#     57416    0.010    0.000    0.010    0.000 {method 'add' of 'set' objects}
#      7500    0.007    0.000    0.010    0.000 <frozen importlib._bootstrap>:405(parent)
#       700    0.001    0.000    0.010    0.000 index.py:158(raw)
#     20912    0.010    0.000    0.010    0.000 {method 'indices' of 'slice' objects}
#      5450    0.006    0.000    0.010    0.000 numpymeta.py:26(purelist_depth)
#      7854    0.007    0.000    0.010    0.000 threading.py:271(__enter__)
#     27274    0.010    0.000    0.010    0.000 array_module.py:326(index_as_shape_item)
#         8    0.000    0.000    0.010    0.001 reading.py:755(root_directory)
#      1800    0.003    0.000    0.010    0.000 regularmeta.py:31(purelist_depth)
#     10570    0.008    0.000    0.010    0.000 content.py:774(<genexpr>)
#         8    0.001    0.000    0.010    0.001 reading.py:1340(__init__)
#     12600    0.007    0.000    0.010    0.000 _layout.py:46(merge_mappings)
#      7500    0.007    0.000    0.010    0.000 misc.py:63(unliteral)
#       750    0.002    0.000    0.010    0.000 fromnumeric.py:2836(min)
#     27136    0.010    0.000    0.010    0.000 {method 'clear' of 'dict' objects}
#       650    0.002    0.000    0.010    0.000 array_module.py:237(<listcomp>)
#     19424    0.009    0.000    0.009    0.000 {method 'index' of 'list' objects}
#      3500    0.006    0.000    0.009    0.000 __init__.py:17(register_and_check)
#     15470    0.009    0.000    0.009    0.000 form.py:381(_init)
#     55928    0.009    0.000    0.009    0.000 TObject.py:23(read_numbytes_version)
#      2162    0.003    0.000    0.009    0.000 _behavior.py:165(behavior_of)
#       150    0.002    0.000    0.009    0.000 _slicing.py:69(prepare_advanced_indexing)
#      1404    0.002    0.000    0.009    0.000 listoffsetform.py:88(type)
#      3600    0.006    0.000    0.009    0.000 _behavior.py:86(find_ufunc_generic)
#     12812    0.007    0.000    0.009    0.000 content.py:1272(find_content_backend)
#      3200    0.008    0.000    0.009    0.000 _ufunc_config.py:132(geterr)
#      5032    0.009    0.000    0.009    0.000 {method 'format' of 'str' objects}
#      1000    0.002    0.000    0.009    0.000 ak_broadcast_arrays.py:233(action)
#      3112    0.008    0.000    0.009    0.000 _behavior.py:154(behavior_of_obj)
#      1230    0.008    0.000    0.009    0.000 threading.py:1501(enumerate)
#     19298    0.009    0.000    0.009    0.000 numpyarray.py:229(length)
#      2500    0.003    0.000    0.009    0.000 listoffsetmeta.py:28(purelist_depth)
#        24    0.000    0.000    0.008    0.000 reading.py:1169(chunk)
#     12812    0.007    0.000    0.008    0.000 record.py:256(find_record_backend)
#     27506    0.008    0.000    0.008    0.000 {method 'upper' of 'str' objects}
#      4450    0.004    0.000    0.008    0.000 indexedmeta.py:44(fields)
#       700    0.008    0.000    0.008    0.000 highlevel.py:2514(__init__)
#     40500    0.008    0.000    0.008    0.000 abstract.py:96(key)
#       150    0.001    0.000    0.008    0.000 indexedarray.py:326(_carry)
#     20890    0.008    0.000    0.008    0.000 _singleton.py:24(_ensure_instance)
#      2162    0.003    0.000    0.008    0.000 _attrs.py:20(attrs_of)
#         8    0.000    0.000    0.008    0.001 fsspec.py:67(_open)
#       500    0.001    0.000    0.008    0.000 listoffsetarray.py:365(_compact_offsets64)
#         8    0.000    0.000    0.008    0.001 spec.py:1280(open)
# 6850/6150    0.006    0.000    0.008    0.000 listoffsetmeta.py:55(fields)
#         8    0.000    0.000    0.008    0.001 local.py:206(_open)
#      2800    0.003    0.000    0.008    0.000 content.py:259(__len__)
#         8    0.000    0.000    0.008    0.001 local.py:376(__init__)
#      3124    0.004    0.000    0.007    0.000 dispatch.py:34(lookup)
#       100    0.000    0.000    0.007    0.000 ak_values_astype.py:15(values_astype)
#     22242    0.006    0.000    0.007    0.000 {method 'join' of 'str' objects}
#      1512    0.002    0.000    0.007    0.000 numpyform.py:136(type)
#        50    0.001    0.000    0.007    0.000 ak_values_astype.py:72(_impl)
#         8    0.000    0.000    0.007    0.001 local.py:389(_open)
#       224    0.001    0.000    0.007    0.000 identify.py:131(_from_leaves)
#     27960    0.007    0.000    0.007    0.000 reading.py:217(options)
#     23870    0.007    0.000    0.007    0.000 highlevel.py:379(layout)
#      2704    0.003    0.000    0.007    0.000 listoffsetmeta.py:39(minmax_depth)
#        50    0.002    0.000    0.007    0.000 recordarray.py:492(_carry)
#      4650    0.003    0.000    0.007    0.000 _broadcasting.py:914(<genexpr>)
#         8    0.000    0.000    0.007    0.001 model.py:401(__exit__)
#         8    0.007    0.001    0.007    0.001 {built-in method io.open}
#      2050    0.005    0.000    0.006    0.000 _parameters.py:122(parameters_union)
#         8    0.000    0.000    0.006    0.001 fsspec.py:95(__exit__)
#     17328    0.006    0.000    0.006    0.000 _behavior.py:21(overlay_behavior)
#      2050    0.001    0.000    0.006    0.000 array_module.py:275(<genexpr>)
#     12836    0.006    0.000    0.006    0.000 {method 'update' of 'dict' objects}
#      9466    0.006    0.000    0.006    0.000 dispatch.py:28(nplike_of_obj)
#     24748    0.006    0.000    0.006    0.000 numpymeta.py:15(purelist_parameters)
#      1566    0.004    0.000    0.006    0.000 _util.py:126(from_module)
#       224    0.001    0.000    0.006    0.000 TTree.py:55(cache_key)
#     18500    0.006    0.000    0.006    0.000 abstract.py:93(__init__)
#         8    0.000    0.000    0.006    0.001 local.py:512(__exit__)
#      7854    0.005    0.000    0.006    0.000 threading.py:274(__exit__)
#      2600    0.005    0.000    0.006    0.000 indexedform.py:26(__init__)
#         8    0.006    0.001    0.006    0.001 {method '__exit__' of '_io._IOBase' objects}
#      3112    0.006    0.000    0.006    0.000 _attrs.py:9(attrs_of_obj)
#      6300    0.006    0.000    0.006    0.000 weakref.py:414(__getitem__)
#      6780    0.004    0.000    0.006    0.000 threading.py:286(_is_owned)
#       750    0.001    0.000    0.006    0.000 {method 'max' of 'numpy.ndarray' objects}
#       553    0.001    0.000    0.006    0.000 fsspec.py:24(add_done_callback)
#      2650    0.002    0.000    0.006    0.000 ak_broadcast_arrays.py:239(<genexpr>)
#      2800    0.004    0.000    0.006    0.000 inspect.py:1745(currentframe)
#      1000    0.002    0.000    0.006    0.000 fromnumeric.py:53(_wrapfunc)
#       250    0.001    0.000    0.006    0.000 array_module.py:453(repeat)
#      2800    0.004    0.000    0.006    0.000 regularmeta.py:19(purelist_parameters)
#     20912    0.006    0.000    0.006    0.000 {built-in method math.ceil}
#      3150    0.003    0.000    0.006    0.000 _slicing.py:181(normalize_integer_like)
#        54    0.000    0.000    0.006    0.000 fsspec.py:228(submit)
#      1700    0.004    0.000    0.006    0.000 _broadcasting.py:217(intersection_parameters_factory)
#      9754    0.006    0.000    0.006    0.000 backend.py:63(maybe_kernel_error)
#     18612    0.006    0.000    0.006    0.000 _errors.py:67(__init__)
#      4600    0.004    0.000    0.006    0.000 highlevel.py:113(prepare_layout)
#      4100    0.004    0.000    0.006    0.000 _broadcasting.py:428(<listcomp>)
#      1512    0.001    0.000    0.005    0.000 numpytype.py:110(__init__)
#     12528    0.005    0.000    0.005    0.000 version.py:207(<genexpr>)
#      3650    0.002    0.000    0.005    0.000 _broadcasting.py:330(<genexpr>)
#      2800    0.004    0.000    0.005    0.000 numpy_support.py:86(from_dtype)
#      6300    0.005    0.000    0.005    0.000 _layout.py:59(__init__)
#      6104    0.005    0.000    0.005    0.000 index.py:221(form)
#       800    0.005    0.000    0.005    0.000 stride_tricks.py:416(_broadcast_shape)
#      1100    0.004    0.000    0.005    0.000 _behavior.py:75(find_custom_cast)
#      8362    0.005    0.000    0.005    0.000 numpyarray.py:175(inner_shape)
#       750    0.001    0.000    0.005    0.000 _methods.py:39(_amax)
#       250    0.001    0.000    0.005    0.000 array_module.py:151(arange)
#      2591    0.005    0.000    0.005    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        54    0.001    0.000    0.005    0.000 tasks.py:917(run_coroutine_threadsafe)
#      5000    0.003    0.000    0.005    0.000 listarray.py:251(length)
#       750    0.001    0.000    0.005    0.000 fromnumeric.py:200(reshape)
#      1150    0.001    0.000    0.005    0.000 indexedmeta.py:28(purelist_depth)
#       553    0.001    0.000    0.005    0.000 _base.py:408(add_done_callback)
#      7850    0.003    0.000    0.005    0.000 _broadcasting.py:431(<genexpr>)
#       150    0.000    0.000    0.005    0.000 indexedarray.py:308(_getitem_field)
#      4400    0.002    0.000    0.005    0.000 _broadcasting.py:434(<genexpr>)
#     10204    0.004    0.000    0.004    0.000 _kernels.py:45(__init__)
#      1150    0.003    0.000    0.004    0.000 _layout.py:178(<setcomp>)
#     27960    0.004    0.000    0.004    0.000 model.py:1376(postprocess)
#      3500    0.002    0.000    0.004    0.000 arrayview.py:254(repr_behavior)
#       224    0.001    0.000    0.004    0.000 identify.py:113(_from_leaves_one)
#     23516    0.004    0.000    0.004    0.000 typing.py:2287(cast)
#      3024    0.002    0.000    0.004    0.000 TBranch.py:1947(num_entries)
#      1200    0.002    0.000    0.004    0.000 listarray.py:239(_touch_data)
#        54    0.004    0.000    0.004    0.000 TBranch.py:3042(<dictcomp>)
#      1450    0.001    0.000    0.004    0.000 typetracer.py:1689(is_own_array)
#       224    0.000    0.000    0.004    0.000 reading.py:1569(cache_key)
#      2912    0.002    0.000    0.004    0.000 numpymeta.py:34(minmax_depth)
#     11070    0.004    0.000    0.004    0.000 threading.py:1168(ident)
#       553    0.001    0.000    0.004    0.000 fsspec.py:27(result)
#     13754    0.004    0.000    0.004    0.000 _layout.py:79(_ensure_not_finalized)
#      1841    0.001    0.000    0.004    0.000 TBasket.py:131(entry_start_stop)
#      3132    0.002    0.000    0.004    0.000 <string>:1(<lambda>)
#      2704    0.003    0.000    0.004    0.000 listoffsetarray.py:810(<genexpr>)
#     18333    0.004    0.000    0.004    0.000 model.py:476(parent)
#     13976    0.004    0.000    0.004    0.000 model.py:497(members)
#      5700    0.002    0.000    0.004    0.000 _broadcasting.py:541(<genexpr>)
#      3682    0.003    0.000    0.004    0.000 queue.py:213(_put)
#     22200    0.004    0.000    0.004    0.000 regulararray.py:166(size)
#        50    0.000    0.000    0.004    0.000 _do.py:237(numbers_to_type)
#     10672    0.004    0.000    0.004    0.000 {method 'values' of 'dict' objects}
#      3200    0.004    0.000    0.004    0.000 {built-in method numpy.seterrobj}
#        56    0.001    0.000    0.004    0.000 reading.py:2251(__init__)
#     41960    0.004    0.000    0.004    0.000 {built-in method builtins.callable}
#      7900    0.004    0.000    0.004    0.000 meta.py:27(parameters)
#        50    0.000    0.000    0.004    0.000 indexedarray.py:767(_numbers_to_type)
#      7500    0.004    0.000    0.004    0.000 {method 'rpartition' of 'str' objects}
#     13748    0.003    0.000    0.003    0.000 {built-in method builtins.min}
#     13054    0.003    0.000    0.003    0.000 {built-in method builtins.iter}
#      3500    0.003    0.000    0.003    0.000 __init__.py:168(_register)
#      7212    0.003    0.000    0.003    0.000 numpyarray.py:171(shape)
#      3132    0.003    0.000    0.003    0.000 version.py:518(<lambda>)
#      1450    0.002    0.000    0.003    0.000 _util.py:31(in_module)
#        54    0.000    0.000    0.003    0.000 base_events.py:805(call_soon_threadsafe)
#      2250    0.003    0.000    0.003    0.000 numpy.py:369(<listcomp>)
#      4950    0.002    0.000    0.003    0.000 numpy.py:422(<genexpr>)
# ...
#      3066    0.001    0.000    0.001    0.000 {method 'popleft' of 'collections.deque' objects}
#      2350    0.001    0.000    0.001    0.000 regularmeta.py:70(content)
#      1566    0.001    0.000    0.001    0.000 python.py:159(_expression_to_function)
#      2600    0.001    0.000    0.001    0.000 indexedform.py:51(content)
#       278    0.000    0.000    0.001    0.000 reading.py:1462(object_path)
#      3568    0.001    0.000    0.001    0.000 __init__.py:181(hook_before_basket_array)
#       800    0.001    0.000    0.001    0.000 _broadcasting.py:148(offset_source_rank)
#      3568    0.001    0.000    0.001    0.000 __init__.py:190(hook_after_basket_array)
#      2336    0.001    0.000    0.001    0.000 {method '__exit__' of '_thread.RLock' objects}
#       100    0.001    0.000    0.001    0.000 array_module.py:689(can_cast)
#      1566    0.001    0.000    0.001    0.000 {method 'mro' of 'type' objects}
#       553    0.001    0.000    0.001    0.000 TBranch.py:3019(replace)
#      2100    0.001    0.000    0.001    0.000 multiarray.py:153(concatenate)
#        40    0.001    0.000    0.001    0.000 {method 'seek' of '_io.BufferedReader' objects}
#      1400    0.001    0.000    0.001    0.000 unionarray.py:423(<genexpr>)
#      1841    0.001    0.000    0.001    0.000 TBasket.py:47(data)
#        54    0.000    0.000    0.001    0.000 arraytype.py:16(__init__)
#       450    0.000    0.000    0.001    0.000 _slicing.py:62(head_tail)
#      1850    0.001    0.000    0.001    0.000 listarray.py:167(starts)
#       104    0.001    0.000    0.001    0.000 {method 'sort' of 'list' objects}
#        16    0.000    0.000    0.000    0.000 jagged.py:123(cache_key)
#      1841    0.000    0.000    0.000    0.000 TBasket.py:58(byte_offsets)
#         8    0.000    0.000    0.000    0.000 {built-in method _hashlib.openssl_md5}
#      1700    0.000    0.000    0.000    0.000 numpy.py:428(<genexpr>)
#       450    0.000    0.000    0.000    0.000 _operators.py:39(_disables_array_ufunc)
#      1700    0.000    0.000    0.000    0.000 _parameters.py:159(parameters_are_empty)
#      1544    0.000    0.000    0.000    0.000 numerical.py:223(to_dtype)
#      1566    0.000    0.000    0.000    0.000 python.py:431(getter)
#         8    0.000    0.000    0.000    0.000 _util.py:325(file_path_to_source_class)
#      2212    0.000    0.000    0.000    0.000 numpymeta.py:30(is_identity_like)
#       108    0.000    0.000    0.000    0.000 library.py:64(empty)
#        16    0.000    0.000    0.000    0.000 numerical.py:279(cache_key)
#      1106    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#      1850    0.000    0.000    0.000    0.000 listarray.py:171(stops)
#        54    0.000    0.000    0.000    0.000 TBranch.py:1096(<listcomp>)
#        54    0.000    0.000    0.000    0.000 fsspec.py:224(loop)
#      1659    0.000    0.000    0.000    0.000 chunk.py:315(start)
#        54    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#       504    0.000    0.000    0.000    0.000 {method 'copy' of 'list' objects}
#       500    0.000    0.000    0.000    0.000 _broadcasting.py:280(<listcomp>)
#       553    0.000    0.000    0.000    0.000 _base.py:398(__get_result)
#      1404    0.000    0.000    0.000    0.000 jagged.py:62(content)
#      1512    0.000    0.000    0.000    0.000 library.py:461(_awkward_add_doc)
#       240    0.000    0.000    0.000    0.000 _util.py:65(ensure_str)
#      1512    0.000    0.000    0.000    0.000 __init__.py:215(hook_after_final_array)
#      1566    0.000    0.000    0.000    0.000 library.py:33(_rename)
#       450    0.000    0.000    0.000    0.000 content.py:272(_maybe_index_error)
#       556    0.000    0.000    0.000    0.000 {method 'newbyteorder' of 'numpy.dtype' objects}
#      1106    0.000    0.000    0.000    0.000 chunk.py:322(stop)
#       208    0.000    0.000    0.000    0.000 jagged.py:54(__init__)
#      1512    0.000    0.000    0.000    0.000 __init__.py:208(hook_before_library_finalize)
#       416    0.000    0.000    0.000    0.000 {method 'findall' of 're.Pattern' objects}
#      1400    0.000    0.000    0.000    0.000 listoffsetmeta.py:24(purelist_isregular)
#      1512    0.000    0.000    0.000    0.000 numerical.py:42(_wrap_almost_finalized)
#       800    0.000    0.000    0.000    0.000 fromnumeric.py:2317(_any_dispatcher)
#      1512    0.000    0.000    0.000    0.000 __init__.py:199(hook_before_final_array)
#       450    0.000    0.000    0.000    0.000 ak_with_field.py:99(action_is_record)
#        32    0.000    0.000    0.000    0.000 numerical.py:281(form)
#       553    0.000    0.000    0.000    0.000 TBasket.py:153(is_embedded)
#       200    0.000    0.000    0.000    0.000 1058244011.py:179(<genexpr>)
#       553    0.000    0.000    0.000    0.000 chunk.py:500(notifier)
#        54    0.000    0.000    0.000    0.000 queue.py:206(_init)
#         8    0.000    0.000    0.000    0.000 _util.py:276(regularize_path)
#        50    0.000    0.000    0.000    0.000 _regularize.py:22(is_sized_iterable)
#        24    0.000    0.000    0.000    0.000 local.py:249(_strip_protocol)
#       750    0.000    0.000    0.000    0.000 fromnumeric.py:2831(_min_dispatcher)
#       224    0.000    0.000    0.000    0.000 numerical.py:186(__init__)
#       416    0.000    0.000    0.000    0.000 identify.py:122(<genexpr>)
#       750    0.000    0.000    0.000    0.000 fromnumeric.py:195(_reshape_dispatcher)
#      1404    0.000    0.000    0.000    0.000 listoffsetmeta.py:35(is_identity_like)
#         8    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#       561    0.000    0.000    0.000    0.000 chunk.py:308(source)
#       666    0.000    0.000    0.000    0.000 recordarray.py:301(is_tuple)
#       108    0.000    0.000    0.000    0.000 coroutines.py:34(iscoroutine)
#         8    0.000    0.000    0.000    0.000 model.py:396(__enter__)
#         8    0.000    0.000    0.000    0.000 _util.py:410(memory_size)
#         8    0.000    0.000    0.000    0.000 __init__.py:163(match)
#       800    0.000    0.000    0.000    0.000 stride_tricks.py:476(_broadcast_arrays_dispatcher)
#       607    0.000    0.000    0.000    0.000 fsspec.py:153(<genexpr>)
#       553    0.000    0.000    0.000    0.000 cursor.py:120(move_to)
#       100    0.000    0.000    0.000    0.000 function_base.py:348(iterable)
#       553    0.000    0.000    0.000    0.000 fsspec.py:20(__init__)
#        32    0.000    0.000    0.000    0.000 _weakrefset.py:39(_remove)
#        50    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#        54    0.000    0.000    0.000    0.000 reading.py:2358(name)
#       508    0.000    0.000    0.000    0.000 recordmeta.py:23(purelist_parameters)
#        16    0.000    0.000    0.000    0.000 fsspec.py:91(__enter__)
#        54    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         8    0.000    0.000    0.000    0.000 TAtt.py:88(read_members)
#       200    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        24    0.000    0.000    0.000    0.000 local.py:474(seek)
#        54    0.000    0.000    0.000    0.000 asyn.py:123(get_loop)
#       650    0.000    0.000    0.000    0.000 array_module.py:45(prepare_ufunc)
#        50    0.000    0.000    0.000    0.000 highlevel.py:584(__len__)
#         8    0.000    0.000    0.000    0.000 fsspec.py:59(extract_fsspec_options)
#       553    0.000    0.000    0.000    0.000 TBasket.py:211(read_numbytes_version)
#       500    0.000    0.000    0.000    0.000 numpymeta.py:22(purelist_isregular)
#        16    0.000    0.000    0.000    0.000 registry.py:241(get_filesystem_class)
#       550    0.000    0.000    0.000    0.000 listmeta.py:24(purelist_isregular)
#       585    0.000    0.000    0.000    0.000 futures.py:85(result)
#        32    0.000    0.000    0.000    0.000 threading.py:283(_acquire_restore)
#         8    0.000    0.000    0.000    0.000 TAtt.py:332(read_members)
#         8    0.000    0.000    0.000    0.000 __init__.py:1467(debug)
#        86    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#       561    0.000    0.000    0.000    0.000 compression.py:509(hook_before_block)
#         8    0.000    0.000    0.000    0.000 config.py:99(apply_config)
#        54    0.000    0.000    0.000    0.000 threading.py:90(RLock)
#        54    0.000    0.000    0.000    0.000 base_events.py:518(_check_closed)
#        50    0.000    0.000    0.000    0.000 worker.py:89(get_worker_info)
#         8    0.000    0.000    0.000    0.000 reading.py:2020(key)
#        70    0.000    0.000    0.000    0.000 reading.py:683(source)
#        54    0.000    0.000    0.000    0.000 fsspec.py:175(<listcomp>)
#        50    0.000    0.000    0.000    0.000 ak_concatenate.py:124(<listcomp>)
#        50    0.000    0.000    0.000    0.000 ak_concatenate.py:148(<listcomp>)
#       250    0.000    0.000    0.000    0.000 fromnumeric.py:419(_repeat_dispatcher)
#       278    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        54    0.000    0.000    0.000    0.000 fsspec.py:176(<listcomp>)
#       250    0.000    0.000    0.000    0.000 regulararray.py:233(_touch_data)
#       150    0.000    0.000    0.000    0.000 numpyarray.py:367(_getitem_next)
#       208    0.000    0.000    0.000    0.000 identify.py:118(<genexpr>)
#        48    0.000    0.000    0.000    0.000 chunk.py:461(remainder)
#        16    0.000    0.000    0.000    0.000 TTree.py:63(num_entries)
#         8    0.000    0.000    0.000    0.000 TBranch.py:2597(_regularize_entries_start_stop)
#        50    0.000    0.000    0.000    0.000 highlevel.py:533(fields)
#         8    0.000    0.000    0.000    0.000 reading.py:1033(decompression_executor)
#       100    0.000    0.000    0.000    0.000 1058244011.py:180(<genexpr>)
#         8    0.000    0.000    0.000    0.000 reading.py:2420(is_compressed)
#         8    0.000    0.000    0.000    0.000 library.py:978(_regularize_library)
#         8    0.000    0.000    0.000    0.000 __init__.py:1734(isEnabledFor)
#         8    0.000    0.000    0.000    0.000 core.py:548(split_protocol)
#       100    0.000    0.000    0.000    0.000 stride_tricks.py:25(_maybe_view_as_subclass)
#       102    0.000    0.000    0.000    0.000 reading.py:2659(fName)
#        24    0.000    0.000    0.000    0.000 local.py:299(make_path_posix)
#        50    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#       200    0.000    0.000    0.000    0.000 stride_tricks.py:345(<genexpr>)
#       224    0.000    0.000    0.000    0.000 reading.py:2350(parent)
#         8    0.000    0.000    0.000    0.000 fsspec.py:63(<dictcomp>)
#       224    0.000    0.000    0.000    0.000 reading.py:1481(file)
#        16    0.000    0.000    0.000    0.000 _util.py:346(<genexpr>)
#        40    0.000    0.000    0.000    0.000 utils.py:327(stringify_path)
#       232    0.000    0.000    0.000    0.000 reading.py:2626(fCycle)
#        24    0.000    0.000    0.000    0.000 reading.py:655(closed)
#        50    0.000    0.000    0.000    0.000 ak_to_layout.py:139(_handle_array_like)
#       154    0.000    0.000    0.000    0.000 recordmeta.py:79(contents)
#         8    0.000    0.000    0.000    0.000 TBranch.py:2643(_regularize_aliases)
#       100    0.000    0.000    0.000    0.000 {method '__exit__' of 'numpy.nditer' objects}
#        32    0.000    0.000    0.000    0.000 threading.py:280(_release_save)
#       232    0.000    0.000    0.000    0.000 TBranch.py:1021(<lambda>)
#        54    0.000    0.000    0.000    0.000 base_events.py:1954(get_debug)
#         7    0.000    0.000    0.000    0.000 local.py:492(closed)
#         8    0.000    0.000    0.000    0.000 TBranch.py:3164(_regularize_step_size)
#        16    0.000    0.000    0.000    0.000 reading.py:2334(data_cursor)
#        54    0.000    0.000    0.000    0.000 model.py:447(file)
#         8    0.000    0.000    0.000    0.000 reading.py:1054(interpretation_executor)
#        16    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#       100    0.000    0.000    0.000    0.000 multiarray.py:503(can_cast)
#        32    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         8    0.000    0.000    0.000    0.000 reading.py:714(object_cache)
#        54    0.000    0.000    0.000    0.000 arraytype.py:35(length)
#        54    0.000    0.000    0.000    0.000 TBranch.py:537(_ak_add_doc)
#         8    0.000    0.000    0.000    0.000 chunk.py:68(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        16    0.000    0.000    0.000    0.000 local.py:508(__enter__)
#         8    0.000    0.000    0.000    0.000 TTree.py:116(aliases)
#        56    0.000    0.000    0.000    0.000 reading.py:2409(is_64bit)
#        54    0.000    0.000    0.000    0.000 recordmeta.py:38(is_identity_like)
#        16    0.000    0.000    0.000    0.000 reading.py:693(object_cache)
#        24    0.000    0.000    0.000    0.000 reading.py:2439(data_compressed_bytes)
#        56    0.000    0.000    0.000    0.000 reading.py:2695(hook_after_interpret)
#        56    0.000    0.000    0.000    0.000 reading.py:2675(hook_before_interpret)
#        32    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        56    0.000    0.000    0.000    0.000 reading.py:2684(hook_before_strings)
#        54    0.000    0.000    0.000    0.000 library.py:138(global_index)
#        32    0.000    0.000    0.000    0.000 numerical.py:206(from_dtype)
#         8    0.000    0.000    0.000    0.000 reading.py:744(array_cache)
#         8    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        32    0.000    0.000    0.000    0.000 numerical.py:287(<genexpr>)
#         8    0.000    0.000    0.000    0.000 futures.py:53(shutdown)
#        24    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         8    0.000    0.000    0.000    0.000 core.py:540(get_compression)
#         8    0.000    0.000    0.000    0.000 reading.py:1013(custom_classes)
#         8    0.000    0.000    0.000    0.000 chunk.py:347(detach_memmap)
#        24    0.000    0.000    0.000    0.000 fsspec.py:214(closed)
#         8    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        32    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#        16    0.000    0.000    0.000    0.000 reading.py:2430(data_uncompressed_bytes)
#         8    0.000    0.000    0.000    0.000 reading.py:259(is_64bit)
#        16    0.000    0.000    0.000    0.000 reading.py:335(fEND)
#         8    0.000    0.000    0.000    0.000 TBranch.py:2616(_regularize_executors)
#         8    0.000    0.000    0.000    0.000 reading.py:1555(is_64bit)
#         8    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         8    0.000    0.000    0.000    0.000 reading.py:1205(hook_before_get_chunks)
#         8    0.000    0.000    0.000    0.000 spec.py:67(<genexpr>)
#         8    0.000    0.000    0.000    0.000 reading.py:1196(hook_before_create_source)
#         8    0.000    0.000    0.000    0.000 core.py:402(<dictcomp>)
#         8    0.000    0.000    0.000    0.000 reading.py:2204(hook_before_header_key)
#         8    0.000    0.000    0.000    0.000 reading.py:2210(hook_before_keys)
#         8    0.000    0.000    0.000    0.000 reading.py:1213(hook_before_interpret)
#         8    0.000    0.000    0.000    0.000 core.py:357(<dictcomp>)
#         8    0.000    0.000    0.000    0.000 reading.py:1220(hook_after_interpret)
#         8    0.000    0.000    0.000    0.000 reading.py:2191(hook_before_interpret)
#         8    0.000    0.000    0.000    0.000 reading.py:2182(hook_before_read)
#         8    0.000    0.000    0.000    0.000 reading.py:2217(hook_after_keys)
#         8    0.000    0.000    0.000    0.000 spec.py:214(_get_kwargs_from_urls)
#         8    0.000    0.000    0.000    0.000 TTree.py:75(tree)
#         8    0.000    0.000    0.000    0.000 reading.py:2197(hook_before_read_keys)

# %%
tensor_dict

# %%
for i in tensor_dict:
    print(i, tensor_dict[i].shape)
# Out:
# MET_phi torch.Size([570])
# nSDVSecVtx torch.Size([570])
# Jet_phi torch.Size([570])
# Jet_pt torch.Size([570])
# Jet_eta torch.Size([570])
# SDVSecVtx_pt torch.Size([570])
# SDVSecVtx_pAngle torch.Size([570])
# SDVSecVtx_charge torch.Size([570])
# SDVSecVtx_ndof torch.Size([570])
# SDVSecVtx_chi2 torch.Size([570])
# SDVSecVtx_tracksSize torch.Size([570])
# SDVSecVtx_sum_tkW torch.Size([570])
# SDVSecVtx_LxySig torch.Size([570])
# SDVSecVtx_L_phi torch.Size([570])
# SDVSecVtx_L_eta torch.Size([570])
# SDVIdxLUT_SecVtxIdx torch.Size([1280])
# SDVIdxLUT_TrackIdx torch.Size([1280])
# SDVTrack_pt torch.Size([570, 10])
# SDVTrack_ptError torch.Size([570, 10])
# SDVTrack_eta torch.Size([570, 10])
# SDVTrack_etaError torch.Size([570, 10])
# SDVTrack_dxy torch.Size([570, 10])
# SDVTrack_dxyError torch.Size([570, 10])
# SDVTrack_dz torch.Size([570, 10])
# SDVTrack_dzError torch.Size([570, 10])
# SDVTrack_normalizedChi2 torch.Size([570, 10])
# SDVTrack_phi torch.Size([570, 10])
# SDVSecVtx_matchedLLPnDau_bydau torch.Size([570])
# SDVTrack_E torch.Size([570, 10])
# SDVTrack_px torch.Size([570, 10])
# SDVTrack_py torch.Size([570, 10])
# SDVTrack_pz torch.Size([570, 10])
